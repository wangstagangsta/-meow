# %%
import sys
import json

import librosa
import numpy as np

# %%
from pathlib import Path
audio_path = Path("..") / "data" / "processed" / "audio_wav" / "Deezl - GHOST.wav"
print(audio_path.resolve())
print("Exists?", audio_path.exists())
y, sr = librosa.load(audio_path, sr=None, mono=True)
print("Loaded:", len(y), "samples at", sr, "Hz")
# Out:
# C:\Users\mplx3\Documents\GitHub\meow\data\processed\audio_wav\Deezl - GHOST.wav
# Exists? True
# Loaded: 8477187 samples at 44100 Hz
